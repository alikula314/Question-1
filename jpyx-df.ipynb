# %%
import numpy as np 
import pandas as pd

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
stock = yf.Ticker("JPY=X")
er = stock.history(period='d', start='2021-1-1', end='2021-1-11')
er.reset_index(level=0, inplace=True)
er = er[['Date', 'Close']]
er["Cur"] = "JPY=X"

# %%
er
